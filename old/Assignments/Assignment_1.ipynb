# %% [markdown]
# # **Machine Learning - Assignment 1**
#
# *These lab assignments are new in the Machine and Deep Learning course. We'd like to hear what you think!*
#
# *Please post any feedback you have on Brightspace. Thanks!*

# %% [markdown]
# ---

# %% [markdown]
# ## Introduction - Basics of Machine Learning
#
# In this assignment, you will go through some of the basic concepts of machine learning. You will learn about the Bayes' rule, decision boundaries, and how to classify simple datasets. You will also get familiar with the PRTools library, which is a toolbox for pattern recognition in Python.
#
# **Prerequisites:**
# * Basic working knowledge of multivariate statistics and linear algebra
# * Basic knowledge of Python and Numpy. Recommended tutorial for Python and Numpy [here](https://cs231n.github.io/python-numpy-tutorial/).
#
# **Learning objectives:**
# * Should be able to mathematically derive decision boundaries given simple probability density functions
# * Should be able to perform simple computations with Bayes’ rule
# * Should be familiar with working under Python
# * Understand some PRTools commands
# * Know what an object and a dataset are
# * Should be able to construct, visualize and classify some simple datasets
#
# **Exercises types:**
# * **Pen \& Paper** - Some exercises will ask you to write down mathematical derivations, calculations, explanations, or simple plots and representations. You can perform these exercises on paper or using a LaTeX editor.
# * **Coding** - Some exercises will ask you to write Python code.

# %% [markdown]
# ---

# %% [markdown]
# ## 1 - Decision Theory (**Pen \& Paper**)

# %% [markdown]
# ### **Exercise 1.1**
#
# #### (a) Gaussian Distributions with Equal Priors
#
# Assume that we managed to represent objects from a two-class classification problem by a single feature. We know that the objects from class $ \omega_1 $ have a Gaussian distribution with $ \mu_1 = 0 $ and $ \sigma_1^2 = \frac{1}{2} $, and the objects from class $ \omega_2 $ have a Gaussian distribution with $ \mu_2 = 1 $ and $ \sigma_2^2 = \frac{1}{2} $.
#
# Derive the position of the decision boundary when both class priors are equal.
#
# #### (b) Uniform Distributions between Different Ranges
#
# Again, assume we have a two-class classification problem in a 1D feature space, but now assume that objects from class $ \omega_1 $ have a uniform distribution between 0 and 1, and objects from class $ \omega_2 $ have a uniform distribution between 2 and 3.
#
# Where is the decision boundary now?
#
# #### (c) Decision Boundary with Overlapping Uniform Distributions
#
# Where is the decision boundary when the objects from class $ \omega_2 $ have a uniform distribution between 0.5 and 1.5? (The distribution of $ \omega_1 $ did not change, classes have equal prior.)
#
# #### (d) Decision Boundary with Extended Uniform Distributions
#
# And where is the decision boundary when the objects from class $ \omega_2 $ have a uniform distribution between 0.5 and 2.5? (The distribution of $ \omega_1 $ did not change, classes have equal prior.)

# %% [markdown]
# ### **Exercise 1.1**
#
# #### (a) Gaussian Distributions with Equal Priors
#
# **Solution:**
#
# The decision boundary is found where the probability density functions (PDFs) of the two classes are equal. For Gaussian distributions, the PDF is given by:
#
# $$
# p(x|\omega_i) = \frac{1}{\sqrt{2\pi\sigma_i^2}} \exp\left(-\frac{(x-\mu_i)^2}{2\sigma_i^2}\right)
# $$
#
# Since the priors are equal, we set the PDFs equal to each other:
#
# $$
# \frac{1}{\sqrt{2\pi\sigma_1^2}} \exp\left(-\frac{(x-\mu_1)^2}{2\sigma_1^2}\right) = \frac{1}{\sqrt{2\pi\sigma_2^2}} \exp\left(-\frac{(x-\mu_2)^2}{2\sigma_2^2}\right)
# $$
#
# Given $\mu_1 = 0$, $\sigma_1^2 = \frac{1}{2}$, $\mu_2 = 1$, and $\sigma_2^2 = \frac{1}{2}$, we simplify:
#
# $$
# \exp\left(-\frac{(x-0)^2}{2 \cdot \frac{1}{2}}\right) = \exp\left(-\frac{(x-1)^2}{2 \cdot \frac{1}{2}}\right)
# $$
#
# $$
# \exp\left(-x^2\right) = \exp\left(-(x-1)^2\right)
# $$
#
# Taking the natural logarithm of both sides:
#
# $$
# -x^2 = -(x-1)^2
# $$
#
# $$
# -x^2 = -x^2 + 2x - 1
# $$
#
# $$
# 0 = 2x - 1
# $$
#
# $$
# x = \frac{1}{2}
# $$
#
# So, the decision boundary is at $x = \frac{1}{2}$.
#
# #### (b) Uniform Distributions between Different Ranges
#
# **Solution:**
#
# For uniform distributions, the decision boundary is where the probability densities are equal. Since the ranges do not overlap, the decision boundary is at the midpoint between the two ranges:
#
# $$
# \text{Decision boundary} = \frac{1 + 2}{2} = 1.5
# $$
#
# So, the decision boundary is at $x = 1.5$.
#
# #### (c) Decision Boundary with Overlapping Uniform Distributions
#
# **Solution:**
#
# For overlapping uniform distributions, the decision boundary is where the probability densities are equal. The probability density for a uniform distribution is the reciprocal of the range length. For $ \omega_1 $ (0 to 1) and $ \omega_2 $ (0.5 to 1.5):
#
# $$
# p(x|\omega_1) = 1 \quad \text{for } 0 \leq x \leq 1
# $$
#
# $$
# p(x|\omega_2) = 1 \quad \text{for } 0.5 \leq x \leq 1.5
# $$
#
# The decision boundary is at the point where the densities are equal, which is at $x = 0.5$.
#
# #### (d) Decision Boundary with Extended Uniform Distributions
#
# **Solution:**
#
# For $ \omega_1 $ (0 to 1) and $ \omega_2 $ (0.5 to 2.5):
#
# $$
# p(x|\omega_1) = 1 \quad \text{for } 0 \leq x \leq 1
# $$
#
# $$
# p(x|\omega_2) = \frac{1}{2} \quad \text{for } 0.5 \leq x \leq 2.5
# $$
#
# The decision boundary is where the densities are equal:
#
# $$
# 1 = \frac{1}{2}
# $$
#
# This occurs at $x = 1$.
#
# So, the decision boundary is at $x = 1$.

# %% [markdown]
# ### **Exercise 1.2**
#
# #### (a) Decision Boundary with Loss Matrix
#
# Assume we represent the objects in a two-class classification problem by a single feature. We know that the objects from class $ \omega_1 $ have a Gaussian distribution with $ \mu_1 = 0 $ and $ \sigma_1^2 = \frac{1}{2} $, and the objects from class $ \omega_2 $ have a Gaussian distribution with $ \mu_2 = 1 $ and $ \sigma_2^2 = \frac{1}{2} $. Derive the position of the decision boundary when both class priors are equal, but we have a loss matrix of:
#
# $$
# L = \begin{pmatrix}
# 0 & 0.5 \\
# 1.0 & 0
# \end{pmatrix}
# $$
#
# #### (b) Decision Boundary with Loss Matrix for Overlapping Uniform Distributions
#
# Assume again we have a two-class classification problem in a 1D feature space, but now assume that objects from class $ \omega_1 $ have a uniform distribution between 0 and 1, and objects from class $ \omega_2 $ have a uniform distribution between 0.5 and 2.5. Given the loss matrix (1.1), where is the decision boundary now?

# %% [markdown]
# ### **Exercise 1.2**
#
# #### (a) Decision Boundary with Loss Matrix
#
# Assume we represent the objects in a two-class classification problem by a single feature. We know that the objects from class $ \omega_1 $ have a Gaussian distribution with $ \mu_1 = 0 $ and $ \sigma_1^2 = \frac{1}{2} $, and the objects from class $ \omega_2 $ have a Gaussian distribution with $ \mu_2 = 1 $ and $ \sigma_2^2 = \frac{1}{2} $. Derive the position of the decision boundary when both class priors are equal, but we have a loss matrix of:
#
# $$
# L = \begin{pmatrix}
# 0 & 0.5 \\
# 1.0 & 0
# \end{pmatrix}
# $$
#
# **Solution:**
#
# The decision boundary is found where the expected loss for both classes is equal. The expected loss for class $ \omega_1 $ and $ \omega_2 $ can be written as:
#
# $$
# r(\omega_1|x) = l^1 p(x|\omega_1) P(\omega_1) + l^2 p(x|\omega_2) P(\omega_2)
# $$
#
# $$
# r(\omega_2|x) = l^1 p(x|\omega_1) P(\omega_1) + l^2 p(x|\omega_2) P(\omega_2)
# $$
#
# Given the loss matrix:
#
# $$
# L = \begin{pmatrix}
# 0 & 0.5 \\
# 1.0 & 0
# \end{pmatrix}
# $$
#
# The expected loss for class $ \omega_1 $ is:
#
# $$
# r(\omega_1|x) = 0 \cdot p(x|\omega_1) P(\omega_1) + 0.5 \cdot p(x|\omega_2) P(\omega_2)
# $$
#
# $$
# r(\omega_1|x) = 0.5 \cdot p(x|\omega_2) P(\omega_2)
# $$
#
# The expected loss for class $ \omega_2 $ is:
#
# $$
# r(\omega_2|x) = 1.0 \cdot p(x|\omega_1) P(\omega_1) + 0 \cdot p(x|\omega_2) P(\omega_2)
# $$
#
# $$
# r(\omega_2|x) = p(x|\omega_1) P(\omega_1)
# $$
#
# Since the priors are equal, $ P(\omega_1) = P(\omega_2) = 0.5 $, we set the expected losses equal to each other:
#
# $$
# 0.5 \cdot p(x|\omega_2) \cdot 0.5 = p(x|\omega_1) \cdot 0.5
# $$
#
# $$
# 0.25 \cdot p(x|\omega_2) = 0.5 \cdot p(x|\omega_1)
# $$
#
# $$
# p(x|\omega_2) = 2 \cdot p(x|\omega_1)
# $$
#
# For Gaussian distributions, the PDF is given by:
#
# $$
# p(x|\omega_i) = \frac{1}{\sqrt{2\pi\sigma_i^2}} \exp\left(-\frac{(x-\mu_i)^2}{2\sigma_i^2}\right)
# $$
#
# Given $\mu_1 = 0$, $\sigma_1^2 = \frac{1}{2}$, $\mu_2 = 1$, and $\sigma_2^2 = \frac{1}{2}$, we simplify:
#
# $$
# \frac{1}{\sqrt{2\pi \cdot \frac{1}{2}}} \exp\left(-\frac{(x-1)^2}{2 \cdot \frac{1}{2}}\right) = 2 \cdot \frac{1}{\sqrt{2\pi \cdot \frac{1}{2}}} \exp\left(-\frac{(x-0)^2}{2 \cdot \frac{1}{2}}\right)
# $$
#
# $$
# \exp\left(-\frac{(x-1)^2}{1}\right) = 2 \cdot \exp\left(-\frac{x^2}{1}\right)
# $$
#
# Taking the natural logarithm of both sides:
#
# $$
# -\frac{(x-1)^2}{1} = \ln(2) - \frac{x^2}{1}
# $$
#
# $$
# -(x-1)^2 = \ln(2) - x^2
# $$
#
# $$
# -x^2 + 2x - 1 = \ln(2) - x^2
# $$
#
# $$
# 2x - 1 = \ln(2)
# $$
#
# $$
# 2x = \ln(2) + 1
# $$
#
# $$
# x = \frac{\ln(2) + 1}{2}
# $$
#
# So, the decision boundary is at $x = \frac{\ln(2) + 1}{2}$.
#
# #### (b) Decision Boundary with Loss Matrix for Overlapping Uniform Distributions
#
# Assume again we have a two-class classification problem in a 1D feature space, but now assume that objects from class $ \omega_1 $ have a uniform distribution between 0 and 1, and objects from class $ \omega_2 $ have a uniform distribution between 0.5 and 2.5. Given the loss matrix (1.1), where is the decision boundary now?
#
# **Solution:**
#
# For uniform distributions, the probability density is the reciprocal of the range length. For $ \omega_1 $ (0 to 1) and $ \omega_2 $ (0.5 to 2.5):
#
# $$
# p(x|\omega_1) = 1 \quad \text{for } 0 \leq x \leq 1
# $$
#
# $$
# p(x|\omega_2) = \frac{1}{2} \quad \text{for } 0.5 \leq x \leq 2.5
# $$
#
# The expected loss for class $ \omega_1 $ is:
#
# $$
# r(\omega_1|x) = 0.5 \cdot \frac{1}{2} \cdot 0.5 = 0.125
# $$
#
# The expected loss for class $ \omega_2 $ is:
#
# $$
# r(\omega_2|x) = 1.0 \cdot 1 \cdot 0.5 = 0.5
# $$
#
# The decision boundary is where the expected losses are equal:
#
# $$
# 0.125 = 0.5
# $$
#
# This occurs at $x = 1$.
#
# So, the decision boundary is at $x = 1$.

# %% [markdown]
# ---

# %% [markdown]
# ### **Exercise 1.3**
#
# In the figure below, two triangular-shaped class conditional probability density functions are given. The first one $ p(x|\omega_1) $ is indicated by a dashed blue line and the second $ p(x|\omega_2) $ with a solid black line. The class priors are assumed equal here.
#
# <img src="assets/Exercise 1.3.png" alt="Exercise 1.3" width="500" style="border: none;">
#
# #### (a) Class Posterior Probabilities Using Bayes' Rule
#
# Use the Bayes' rule to derive the class posterior probabilities of the following objects: $ x = 3 $, $ x = -0.5 $, $ x = +0.5 $. To which class are the objects therefore assigned?
#
# #### (b) Decision Boundary of the Bayes Classifier
#
# Which object is on the decision boundary of the Bayes classifier?
#
# ### **Exercise 1.3**
#
# #### (a) Class Posterior Probabilities Using Bayes' Rule
#
# Given:
# - The class conditional probability density functions $ p(x|\omega_1) $ and $ p(x|\omega_2) $.
# - The class priors are equal, i.e., $ P(\omega_1) = P(\omega_2) = 0.5 $.
#
# The class posterior probabilities can be calculated using Bayes' Rule:
#
# $ P(\omega_i|x) = \frac{p(x|\omega_i)P(\omega_i)}{p(x)} $
#
# The distribution of $ \omega_1 $ is a triangle with points (-1,0), (0,1), (1,0).
# The distribution of $ \omega_2 $ is a triangle with points (0,0), (2,0.5), (4,0).
#
#
# ##### 1. $ x = 3 $
#
# For $ P(\omega_1|3) $:
# - Since $ x = 3 $ is outside the range of $ \omega_1 $, $ p(3|\omega_1) = 0 $.
# - So $ P(\omega_1|3) = \frac{0 \cdot 0.5}{p(3)} = 0 $.
#
# For $ P(\omega_2|3) $:
# - Substitute $ x = 3 $ into the line formula that represents the distribution for class $ \omega_2 $ to between (0,0) and (2,0.5) to find $ p(3|\omega_2) $.
#     - $ y = 1/4 * x $ => $ y = 1/4 * 3 = 3/4 $.
#
# $ P(x) = P(x|\omega_1)P(\omega_1) + P(x|\omega_2)P(\omega_2) = 0 + 3/4 * 0.5 = 3/8 $
#
# $ P(\omega_1|3) = \frac{p(3|\omega_1)P(\omega_1)}{P(3)} = \frac{0 \cdot 0.5}{3/8} = 0 $
#
# $ P(\omega_2|3) = \frac{p(3|\omega_2)P(\omega_2)}{P(3)} = \frac{3/4 \cdot 0.5}{3/8} = 1 $
#
#
# ##### 2. $ x = -0.5 $
#
# Similar as for $ x = 3 $.
#     - $ x = -0.5 $ is outside the range of $ \omega_2 $ => $ p(-0.5|\omega_2) = 0 $.
#     - $ P(\omega_2|-0.5) = 1 $
#
# ##### 3. $ x = 0.5 $
#
# Substitute $ x = 0.5 $ into the line formula that represents the distribution for class $\omega_1$ to between (0,1) and (1,0) to find $ p(0.5|\omega_1) $.
# -   $ y = -x + 1 $ => $ y = -0.5 + 1 = 1/2 $
#
# Substitute $ x = 0.5 $ into the line formula that represents the distribution for class $\omega_2$ to between (0,0) and (2,1/2) to find $ p(0.5|\omega_2) $.
# -   $ y = 1/4 * x $ => $ y = 1/4 * 0.5 = 1/8 $
#
# $ P(x) = P(x|\omega_1)P(\omega_1) + P(x|\omega_2)P(\omega_2) = 0.5 * 0.5 + 1/8 * 0.5 = 1/4 + 1/16 = 5/16 $
#
# $ P(\omeg
#
#
#
# #### (b) Decision Boundary of the Bayes Classifier
#
# To find the decision boundary of the Bayes classifier, we need to determine the point where the posterior probabilities of the two classes are equal. This means:
#
# $ P(\omega_1|x) = P(\omega_2|x) $
#
# Since the priors are equal, this simplifies to:
#
# $ p(x|\omega_1) = p(x|\omega_2) $
#
# We need to find the value of $ x $ where the class conditional densities are equal.
#
# Given the distributions:
# - $ p(x|\omega_1) $ is a triangle with points (-1,0), (0,1), (1,0).
# - $ p(x|\omega_2) $ is a triangle with points (0,0), (2,1/2), (4,0).
#
# Let's find the equations of the lines for each segment of the triangles.
#
# For $ p(x|\omega_1) $:
# - From (-1,0) to (0,1): $ y = x + 1 $
# - From (0,1) to (1,0): $ y = -x + 1 $
#
# For $ p(x|\omega_2) $:
# - From (0,0) to (2,1/2): $ y = \frac{1}{4}x $
# - From (2,1/2) to (4,0): $ y = -\frac{1}{4}x + 1 $
#
# We need to find the intersection of these lines to determine the decision boundary, but not all intersections are relevant. We need to find the intersection points that are within the range of the distributions.
#
# The only relevant intersection point is the intersection of $ y = -x + 1 $ and $ y = \frac{1}{4}x $:
#
# $ -x + 1 = \frac{1}{4}x $
#
# $ 1 = \frac{5}{4}x $
#
# $ x = \frac{4}{5} = 0.8 $
#
# So, the decision boundary is at $ x = 0.8 $.
#
# Therefore, the object at $ x = 0.8 $ is on the decision boundary of the Bayes classifier.

# %% [markdown]
# ### **Exercise 1.4**
#
# $$
# P(x|\omega_1) =
# \begin{cases}
# x+1 & \text{if } -1 \le  x \le 0 \\
# -x+1 & \text{if } 0 \le x \le 1 \\
# 0 & \text{if } \text{otherwise}
# \end{cases}
# $$
#
# $$
# P(x|\omega_2) =
# \begin{cases}
# \frac{1}{4}x & \text{if } 0 \le x \le 2 \\
# -\frac{1}{4}x+1 & \text{if } 2 \le x \le 4 \\
# 0 & \text{if } \text{otherwise}
# \end{cases}
# $$
#
#
# Now assume that class $ \omega_1 $ in the figure is twice as small as class $ \omega_2 $. That means $ p(\omega_1) = \frac{1}{3} $ and $ p(\omega_2) = \frac{2}{3} $.
#
# #### (a) Posterior Probabilities with Updated Priors
#
# Compute the posterior probabilities for $ x = 3 $, $ x = -0.5 $, $ x = 0.5 $.
#
# #### (b) Decision Boundary with Updated Priors
#
# Where is the decision boundary of the Bayes classifier now?

# %% [markdown]
# #### (a) Posterior Probabilities with Updated Priors
#
# To compute the posterior probabilities, we use Bayes' theorem:
#
# $$
# P(\omega_i|x) = \frac{P(x|\omega_i)P(\omega_i)}{P(x)}
# $$
#
# where $ P(x) $ is the total probability of $ x $:
#
# $$
# P(x) = P(x|\omega_1)P(\omega_1) + P(x|\omega_2)P(\omega_2)
# $$
#
# Let's compute the posterior probabilities for each given $ x $:
#
# 1. **For $ x = 3 $**:
#
#    - $ P(x|\omega_1) = 0 $ (since $ x = 3 $ is outside the range of $ P(x|\omega_1) $)
#    - $ P(x|\omega_2) = -\frac{1}{4}x + 1 = -\frac{1}{4}(3) + 1 = -\frac{3}{4} + 1 = \frac{1}{4} $
#
#    Total probability $ P(x) $:
#
#    $$
#    P(x) = P(x|\omega_1)P(\omega_1) + P(x|\omega_2)P(\omega_2) = 0 \cdot \frac{1}{3} + \frac{1}{4} \cdot \frac{2}{3} = \frac{1}{6}
#    $$
#
#    Posterior probabilities:
#
#    $$
#    P(\omega_1|x) = \frac{0 \cdot \frac{1}{3}}{\frac{1}{6}} = 0
#    $$
#
#    $$
#    P(\omega_2|x) = \frac{\frac{1}{4} \cdot \frac{2}{3}}{\frac{1}{6}} = 1
#    $$
#
# 2. **For $ x = -0.5 $**:
#
#    - $ P(x|\omega_1) = x + 1 = -0.5 + 1 = 0.5 $
#    - $ P(x|\omega_2) = 0 $ (since $ x = -0.5 $ is outside the range of $ P(x|\omega_2) $)
#
#    Total probability $ P(x) $:
#
#    $$
#    P(x) = P(x|\omega_1)P(\omega_1) + P(x|\omega_2)P(\omega_2) = 0.5 \cdot \frac{1}{3} + 0 \cdot \frac{2}{3} = \frac{1}{6}
#    $$
#
#    Posterior probabilities:
#
#    $$
#    P(\omega_1|x) = \frac{0.5 \cdot \frac{1}{3}}{\frac{1}{6}} = 1
#    $$
#
#    $$
#    P(\omega_2|x) = \frac{0 \cdot \frac{2}{3}}{\frac{1}{6}} = 0
#    $$
#
# 3. **For $ x = 0.5 $**:
#
#    - $ P(x|\omega_1) = -x + 1 = -0.5 + 1 = 0.5 $
#    - $ P(x|\omega_2) = \frac{1}{4}x = \frac{1}{4}(0.5) = \frac{1}{8} $
#
#    Total probability $ P(x) $:
#
#    $$
#    P(x) = P(x|\omega_1)P(\omega_1) + P(x|\omega_2)P(\omega_2) = 0.5 \cdot \frac{1}{3} + \frac{1}{8} \cdot \frac{2}{3} = \frac{1}{6} + \frac{1}{12} = \frac{1}{4}
#    $$
#
#    Posterior probabilities:
#
#    $$
#    P(\omega_1|x) = \frac{0.5 \cdot \frac{1}{3}}{\frac{1}{4}} = \frac{2}{3}
#    $$
#
#    $$
#    P(\omega_2|x) = \frac{\frac{1}{8} \cdot \frac{2}{3}}{\frac{1}{4}} = \frac{1}{3}
#    $$
#
# #### (b) Decision Boundary with Updated Priors
#
# The decision boundary is where the posterior probabilities are equal:
#
# $$
# P(\omega_1|x) = P(\omega_2|x)
# $$
#
# Using Bayes' theorem:
#
# $$
# \frac{P(x|\omega_1)P(\omega_1)}{P(x)} = \frac{P(x|\omega_2)P(\omega_2)}{P(x)}
# $$
#
# Since $ P(x) $ is common, we can simplify to:
#
# $$
# P(x|\omega_1)P(\omega_1) = P(x|\omega_2)P(\omega_2)
# $$
#
# Substitute the given priors $ P(\omega_1) = \frac{1}{3} $ and $ P(\omega_2) = \frac{2}{3} $:
#
# $$
# P(x|\omega_1) \cdot \frac{1}{3} = P(x|\omega_2) \cdot \frac{2}{3}
# $$
#
# $$
# P(x|\omega_1) = 2P(x|\omega_2)
# $$
#
# We need to find $ x $ such that this equation holds. By examining the piecewise functions, we find that the decision boundary occurs at the point where the likelihoods are equal, considering the priors. This requires solving for $ x $ in the ranges where both $ P(x|\omega_1) $ and $ P(x|\omega_2) $ are non-zero.
#
# After solving, we find that the decision boundary is at $ x = 1 $.

# %% [markdown]
# ### **Exercise 1.5**
#
# Compute the Bayes error for the class distributions given in the figure above, where the classes have equal prior.

# %% [markdown]
# #### Bayes Error Calculation
#
# The Bayes error is the probability of misclassification by the Bayes classifier. It is given by the integral of the minimum of the class-conditional probabilities, weighted by the priors. Since the priors are equal, $ P(\omega_1) = P(\omega_2) = \frac{1}{2} $.
#
# The Bayes error $ P_e $ is given by:
#
# $$
# P_e = \int_{-\infty}^{\infty} \min \left( P(x|\omega_1)P(\omega_1), P(x|\omega_2)P(\omega_2) \right) dx
# $$
#
# Given the class-conditional probabilities:
#
# $$
# P(x|\omega_1) =
# \begin{cases}
# x+1 & \text{if } -1 \le  x \le 0 \\
# -x+1 & \text{if } 0 \le x \le 1 \\
# 0 & \text{if } \text{otherwise}
# \end{cases}
# $$
#
# $$
# P(x|\omega_2) =
# \begin{cases}
# \frac{1}{4}x & \text{if } 0 \le x \le 2 \\
# -\frac{1}{4}x+1 & \text{if } 2 \le x \le 4 \\
# 0 & \text{if } \text{otherwise}
# \end{cases}
# $$
#
# Since the priors are equal, we have:
#
# $$
# P(\omega_1) = P(\omega_2) = \frac{1}{2}
# $$
#
# We need to find the regions where $ P(x|\omega_1) $ and $ P(x|\omega_2) $ overlap and compute the integral of the minimum of these probabilities.
#
# 1. **For $ -1 \le x \le 0 $**:
#
#    - $ P(x|\omega_1) = x + 1 $
#    - $ P(x|\omega_2) = 0 $
#
#    Since $ P(x|\omega_2) = 0 $, the minimum is $ 0 $.
#
# 2. **For $ 0 \le x \le 1 $**:
#
#    - $ P(x|\omega_1) = -x + 1 $
#    - $ P(x|\omega_2) = \frac{1}{4}x $
#
#    The minimum is $ \frac{1}{4}x $ because $ \frac{1}{4}x \le -x + 1 $ in this range.
#
# 3. **For $ 1 \le x \le 2 $**:
#
#    - $ P(x|\omega_1) = 0 $
#    - $ P(x|\omega_2) = \frac{1}{4}x $
#
#    Since $ P(x|\omega_1) = 0 $, the minimum is $ 0 $.
#
# 4. **For $ 2 \le x \le 4 $**:
#
#    - $ P(x|\omega_1) = 0 $
#    - $ P(x|\omega_2) = -\frac{1}{4}x + 1 $
#
#    Since $ P(x|\omega_1) = 0 $, the minimum is $ 0 $.
#
# Now, we integrate the minimum values over the respective ranges:
#
# $$
# P_e = \int_{0}^{1} \frac{1}{4}x \cdot \frac{1}{2} dx
# $$
#
# $$
# P_e = \frac{1}{8} \int_{0}^{1} x \, dx
# $$
#
# $$
# P_e = \frac{1}{8} \left[ \frac{x^2}{2} \right]_{0}^{1}
# $$
#
# $$
# P_e = \frac{1}{8} \cdot \frac{1}{2}
# $$
#
# $$
# P_e = \frac{1}{16}
# $$
#
# So, the Bayes error for the given class distributions with equal priors is $ \frac{1}{16} $.

# %% [markdown]
# Before moving on to the coding exercises for this week, let's first revise some basic concepts of the PRTools library.

# %% [markdown]
# ### **Tutorial** - PRTools Basics

# %%
# !pip install git+https://github.com/DMJTax/prtools.git
# Out:
# Collecting git+https://github.com/DMJTax/prtools.git
#   Cloning https://github.com/DMJTax/prtools.git to /tmp/pip-req-build-7t49eig9
#   Running command git clone --filter=blob:none --quiet https://github.com/DMJTax/prtools.git /tmp/pip-req-build-7t49eig9
#   Resolved https://github.com/DMJTax/prtools.git to commit 38dee74c266c54a1c75318390edc21a87668264f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from prtools==1.2.1) (1.5.2)
# Requirement already satisfied: numpy in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from prtools==1.2.1) (2.1.1)
# Requirement already satisfied: matplotlib in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from prtools==1.2.1) (3.9.2)
# Requirement already satisfied: requests in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from prtools==1.2.1) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (24.1)
# Requirement already satisfied: pillow>=8 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from matplotlib->prtools==1.2.1) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from requests->prtools==1.2.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from requests->prtools==1.2.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from requests->prtools==1.2.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from requests->prtools==1.2.1) (2024.8.30)
# Requirement already satisfied: scipy>=1.6.0 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from scikit-learn->prtools==1.2.1) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from scikit-learn->prtools==1.2.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from scikit-learn->prtools==1.2.1) (3.5.0)
# Requirement already satisfied: six>=1.5 in /home/tmw/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->prtools==1.2.1) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import prtools as pr

# %%
# Use the following code to create a dummy dataset containing 10 objects with 2 features each.

x = np.array(
    [[1, 5], [4, 5], [7, 8],
    [10, 11], [11, 14], [16, 17],
    [19, 20], [22, 2], [25, 23],
    [28, 20]]
    )

# %%
#To compute the means and std of the features, you can use the available numpy functions.

# The 'axis' parameter specifies the dimension along which the mean/std should be computed.

# If axis=0, the mean/std is computed for each feature across all objects.

mean = np.mean(x, axis=0)
std = np.std(x, axis=0)

print('Mean:', mean)
print('Std:', std)
print()

# If axis=1, the mean/std is computed for each object across all features.

mean = np.mean(x, axis=1)
std = np.std(x, axis=1)

print('Mean:', mean)
print('Std:', std)
print()

# If the parameter is not specified, the mean/std is computed for all elements in the array.

mean = np.mean(x)
std = np.std(x)

print('Mean:', mean)
print('Std:', std)
# Out:
# Mean: [14.3 12.5]
# Std: [8.67236992 7.00357052]
#
# Mean: [ 3.   4.5  7.5 10.5 12.5 16.5 19.5 12.  24.  24. ]
# Std: [ 2.   0.5  0.5  0.5  1.5  0.5  0.5 10.   1.   4. ]
#
# Mean: 13.4
# Std: 7.933473388119481

# %%
#When a dataset contains just two features per object, it can be visualized in a scatterplot
feature1 = x[:, 0]
feature2 = x[:, 1]
plt.scatter(feature1, feature2)

# %%
#You can create labels for the previously generated data by defining another numpy array

lab = np.array([1,1,1,1,2,2,2,2,2,2]).reshape(10,1)
#lab = np.array([[1,1,1,1,2,2,2,2,2,2]]).T # alternative

#Then, you can create a PRTools dataset using the prdataset function

a = pr.prdataset(x,lab)
print(a)
# Out:
# 10 by 2 prdataset with 2 classes: [4 6]

# %%
#If visualized, it will show the labels in different colors

pr.scatterd(a)

# %%
#There is a set of predefined datasets in PRTools that can be loaded using
#functions as gendatb, gendatc, gendats ...

#For instance, to load a Banana shaped dataset, you can use the following line

b = pr.gendatb()
print(b)

#... and then visualize it
pr.scatterd(b)

#Other datasets that can be loaded in the same way:

# - gendatc: generation of circular classes
# - gendats: generation of two Gaussian classes
# - gendatd: generation of two difficult classes
# - gendath: generation of the hygleyman dataset
# ... and more!
# Out:
# Banana dataset 100 by 2 prdataset with 2 classes: [50 50]

# %%
#Assume we want to train a nearest mean classifier on the defined Banana dataset. In PRTools you do:

w = pr.nmc()
w.train(b)
print(w) # this will show the classifier parameters

c = w.eval(b)
print(c)

e = pr.testc(c)
print(e) # this will show the classification error

#to visualize the decision boundary of the classifier, you can use the following code

pr.scatterd(b)
pr.plotc(w)
# Out:
# Nearest mean, 2 to 2 trained mapping
# Banana dataset 100 by 2 prdataset with 2 classes: [50 50]
# 0.2

# %%
#Some classifiers require additional hyperparameters to be specified.
#For instance, in the support vector classifier, you can specify the kernel, a kernel parameter, and a regularisation parameter.
#Or in the k-nearest neighbor classifier you can specify the number of neighbors k.
#You can supply that as additional input during training. For example, for svc:

w = pr.svc(('rbf',4.5,1 ))
w.train(b)
print(w)

c = w.eval(b)
print(c)

e = pr.testc(c)
print(e)

pr.scatterd(b)
pr.plotc(w)
# Out:
# Support vector classifier, 2 to 2 trained mapping
# Banana dataset 100 by 2 prdataset with 2 classes: [50 50]
# 0.02

# %%
#... or for knnc:

w = pr.knnc(3)
w.train(b)
print(w)

c = w.eval(b)
print(c)

e = pr.testc(c)
print(e)

pr.scatterd(b)
pr.plotc(w)
# Out:
# 3-NN+Bayes rule, 2 to 2 trained mapping
# Banana dataset 100 by 2 prdataset with 2 classes: [50 50]
# 0.01

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - Creating Maps and Decision Boundaries (**Coding**)
#
# So far, we have visualized the decision boundary and computed the classification error on a the training set. However, the classification error on the training set is not a good indicator of the performance of the classifier. Here is a complete example of training a svc classifier and visualizing the decision boundary and classification error on a test set.

# %%
#Create hard training dataset using gendatd

d = pr.gendatd()
print(d)

#Train a ldc classifier on the dataset

w = pr.svc()
w.train(d)

#Evaluate the classifier on the training set

c = w.eval(d)
print(c)

e = pr.testc(c)
print(e)

#Visualize the training set

pr.scatterd(d)
pr.plotc(w)
# Out:
# Difficult dataset 40 by 2 prdataset with 2 classes: [20 20]
# Difficult dataset 40 by 2 prdataset with 2 classes: [20 20]
# 0.025

# %%
#Create a test dataset using gendatd

t = pr.gendatd()
print(t)

#Evaluate the classifier on the test set

c = w.eval(t)
print(c)

e = pr.testc(c)
print(e)

#Visualize the test set

pr.scatterd(t)
pr.plotc(w)
# Out:
# Difficult dataset 40 by 2 prdataset with 2 classes: [20 20]
# Difficult dataset 40 by 2 prdataset with 2 classes: [20 20]
# 0.325

# %% [markdown]
# ### **Exercise 2.1**
#
# Train the following classifiers on some 2D datasets and visualize the decision boundaries. Also visualize the error on the test set.
#
# **Classifiers:**
# * ldc -> Linear discriminant analysis
# * qdc -> Quadratic discriminant analysis
# * nmc -> Nearest mean classifier
# * fisherc -> Fishers linear discriminant
# * knnc -> k-nearest neighbor classifier
# * parzenc -> Parzen classifier
# * naivebc -> Naive-Bayes classifier
# * mogc -> Mixture-of-Gaussians classifier
# * stumpc -> Decision stump classifier
# * dectreec -> Decision tree classifier
# * adaboostc -> AdaBoost
# * svc -> Support vector classifier

# %%
import numpy as np
import matplotlib.pyplot as plt
import prtools as pr

# Import banana dataset
bannana_dataset = pr.gendatb()

# Linear Discriminant Analysis
ldc_classifier = pr.ldc()
ldc_classifier.train(bannana_dataset)

# Plot the banana dataset and LDA decision boundary
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(ldc_classifier)
plt.title('Linear Discriminant Analysis')
plt.show()

# Quadratic Discriminant Analysis
qdc_classifier = pr.qdc()
qdc_classifier.train(bannana_dataset)

# Plot the banana dataset and QDA decision boundary
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(qdc_classifier)
plt.title('Quadratic Discriminant Analysis')
plt.show()


# Nearest mean classifier
nmc_classifier = pr.nmc()
nmc_classifier.train(bannana_dataset)

# Plot the banana dataset and NMC decision boundary
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(nmc_classifier)
plt.title('Nearest Mean Classifier')
plt.show()

# Fishers linear discriminant
fisher_classifier = pr.fisherc()
fisher_classifier.train(bannana_dataset)
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(fisher_classifier)
plt.title('Fishers Linear Discriminant')
plt.show()

# k-nearest neighbor classifier
knnc_classifier = pr.knnc()
knnc_classifier.train(bannana_dataset)
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(knnc_classifier)
plt.title('k-Nearest Neighbor Classifier')
plt.show()

# Parzen classifier
parzenc_classifier = pr.parzenc()
parzenc_classifier.train(bannana_dataset)
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(parzenc_classifier)
plt.title('Parzen Classifier')
plt.show()

# Naive-Bayes classifier
naivebc_classifier = pr.naivebc()
naivebc_classifier.train(bannana_dataset)
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(naivebc_classifier)
plt.title('Naive-Bayes Classifier')
plt.show()

# Mixture-of-Gaussians classifier
mogc_classifier = pr.mogc()
mogc_classifier.train(bannana_dataset)
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(mogc_classifier)
plt.title('Mixture-of-Gaussians Classifier')
plt.show()

# Decision stump classifier
# stumpc_classifier = pr.stumpc()
# stumpc_classifier.train(bannana_dataset)
# plt.figure()
# pr.scatterd(bannana_dataset)
# pr.plotc(stumpc_classifier)
# plt.title('Decision Stump Classifier')
# plt.show()

# Decision tree classifier
dectreec_classifier = pr.dectreec()
dectreec_classifier.train(bannana_dataset)
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(dectreec_classifier)
plt.title('Decision Tree Classifier')
plt.show()

# # AdaBoost
# adaboostc_classifier = pr.adaboostc()
# adaboostc_classifier.train(bannana_dataset)
# plt.figure()
# pr.scatterd(bannana_dataset)
# pr.plotc(adaboostc_classifier)
# plt.title('AdaBoost Classifier')
# plt.show()

# Support vector classifier
svc_classifier = pr.svc()
svc_classifier.train(bannana_dataset)
plt.figure()
pr.scatterd(bannana_dataset)
pr.plotc(svc_classifier)
plt.title('Support Vector Classifier')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 3 - Classification with Normal Densities (**Coding**)

# %% [markdown]
# ### **Exercise 3.1**
#
# Consider two 2D normal distributions with different means but equal covariance matrices.

# %% [markdown]
# #### (a) Shape of the Optimal Decision Boundary
#
# What shape does the optimal decision boundary have?
#
# Generate 10 data points per class from a data set that fulfills the above assumptions. Create a data set with these 20 points and these two classes. We can estimate linear discriminants by means of `ldc(a)` and quadratic discriminant boundaries by means of `qdc(a)`.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA

# Set random seed for reproducibility
np.random.seed(42)

# Define the means of the two distributions
mean1 = [2, 2]
mean2 = [5, 5]

# Define the common covariance matrix
cov = [[1, 0.5], [0.5, 1]]

# Generate 10 data points for each class
class1 = np.random.multivariate_normal(mean1, cov, 10)
class2 = np.random.multivariate_normal(mean2, cov, 10)

# Combine the data points into one dataset
X = np.vstack((class1, class2))
y = np.array([0]*10 + [1]*10)  # Labels: 0 for class1, 1 for class2

# Plot the data points
plt.scatter(class1[:, 0], class1[:, 1], label='Class 1')
plt.scatter(class2[:, 0], class2[:, 1], label='Class 2')
plt.legend()
plt.title('Generated Data Points')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# Linear Discriminant Analysis (LDA)
lda = LDA()
lda.fit(X, y)

# Plot the linear decision boundary
x_vals = np.linspace(min(X[:, 0]), max(X[:, 0]), 100)
y_vals = -(lda.coef_[0][0] * x_vals + lda.intercept_[0]) / lda.coef_[0][1]
plt.plot(x_vals, y_vals, label='LDA Decision Boundary', color='red')

# Quadratic Discriminant Analysis (QDA)
qda = QDA()
qda.fit(X, y)

# Plot the quadratic decision boundary
xx, yy = np.meshgrid(np.linspace(min(X[:, 0]), max(X[:, 0]), 100),
                     np.linspace(min(X[:, 1]), max(X[:, 1]), 100))
Z = qda.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, levels=[0.5], linestyles='dashed', colors='blue')

# Plot the data points again
plt.scatter(class1[:, 0], class1[:, 1], label='Class 1')
plt.scatter(class2[:, 0], class2[:, 1], label='Class 2')
plt.legend()
plt.title('LDA and QDA Decision Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# #### (b) Shape of the Quadratic Discriminant Boundary
#
# Given the shape of the optimal decision boundary, how does the boundary look for the trained normal density-based quadratic discriminant?
#
# The PRTools command `plotc` plots the decision boundary. If you plotted decision boundaries of multiple classifiers in one plot command `pr.plotc([w1, w2])`, you will get a legend.

# %%
#Write your solution here

# %% [markdown]
# #### (c) Scatter Plot and Decision Boundaries
#
# Scatter the data set and plot the decision boundary estimated by means of `ldc(a)` and `qdc(a)`. Can you explain their difference? You might want to revisit the previous question (b).

# %%
#Write your solution here

# %% [markdown]
# #### (d) Increasing Number of Data Points
#
# What happens when the number of points per class increases? What happens in the limit of an infinite number of points?

# %% [markdown]
# ---

# %% [markdown]
# ## 4 - Density estimation using Parzen densities **(Coding)**

# %% [markdown]
# Next to classifiers, PRTools also has the possibility to estimate densities. In this section we are going to estimate the density using a Parzen density estimator, called parzenm in PRTools

# %%
#We start with creating a simple dataset with:
a = pr.gendats([20,20],1,8)

#We define the width parameter h for the Parzen kernel:
h = 0.5

#The function parzenm estimates a density for a given dataset. In most cases a PRTools prdataset is labeled, and these labels are used in the function parzenm to estimate a density for each class. To define a Parzen density estimator with a certain width parameter h on the entire dataset, ignoring labels, type:
a = pr.prdataset(+a)
w = pr.parzenm(a,h)

#This mapping can now be plotted along with the data:
pr.scatterd(a)
pr.plotm(w)

#If your graphs look a little “bumpy”, you can increase the grid size PRTools uses for plotting:

pr.plotm(w,gridsize=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 13
#      11 #This mapping can now be plotted along with the data:
#      12 pr.scatterd(a)
# ---> 13 pr.plotm(w)
#      15 #If your graphs look a little “bumpy”, you can increase the grid size PRTools uses for plotting:
#      17 pr.plotm(w,gridsize=100)
#
# File ~/PycharmProjects/Master-MLDL/venv/lib/python3.12/site-packages/prtools/mapping.py:572, in plotm(f, nrlevels, colors, gridsize)
#     570 ax = plt.gca()
#     571 if colors is None:
# --> 572     colors = next(ax._get_lines.prop_cycler)["color"]
#     573 xl = ax.get_xlim()
#     574 dx = (xl[1] - xl[0]) / (gridsize - 1)
#
# AttributeError: '_process_plot_var_args' object has no attribute 'prop_cycler'

# %% [markdown]
# When you want to evaluate the fit of a density model to some data, you have to define an error. One possibility is to use the log-likelihood, defined as:
#
# $$
# LL(X) = \log \prod_i \hat{p}(x_i) = \sum_i \log(\hat{p}(x_i)) \tag{1.2}
# $$
#
# The better the data $x$ fits in the probability density model $\hat{p}$, the higher the values of $\hat{p}(x)$ will be. This will result in a high value of $\sum_i \log(\hat{p}(x_i))$. When we have different probability density estimates $\hat{p}$, we use the one which has the highest value of $LL$.
#
# Note that when we fill in different values for the width parameters $h$ in the Parzen density estimation, we have different estimates $\hat{p}$. Using the log-likelihood as a criterion, we can optimize the value of this free parameter $h$ to maximize $LL$.
#
# To get an honest estimate of the log-likelihood, we have to evaluate the log-likelihood (1.2) on a test set. That means that we have to make (or measure) new data from the same distribution as where the training data came from. When we evaluate the log-likelihood on the data on which the probability density was fitted, we would get a too optimistic estimation of the error. We might conclude that we have fitted the data very well, while actually a new dataset from the same distribution does not fit in the density at all! Therefore, if you want to evaluate the performance of an estimated $\hat{p}$, use an independent test set!

# %% [markdown]
# ### **Exercise 4.1**

# %% [markdown]
# Use the data from the same distribution as in the previous exercise to train a Parzen density estimator for different values of h. Compute the log-likelihood of this training set given the estimated densities (for different $h$)

# %%
a = pr.gendats([20,20],1,8)                 # Generate data
a = pr.prdataset(+a)
hs = [0.01,0.05,0.1,0.25,0.5,1,1.5,2,3,4,5] # Array of h’s to try
LL = np.zeros(len(hs))
for i in range(len(hs)):
                                         # For each h...
    w = pr.parzenm(a,hs[i])                  #   estimate Parzen density
    LL[i] = np.sum(np.log(+(a*w)))        #   calculate log-likelihood
plt.plot(hs,LL)
plt.xlabel('h')
plt.ylabel('log-likelihood')
plt.title('Parzen density estimation')
plt.show()

# %% [markdown]
# What is the optimal value for h, i.e. the maximal likelihood? Is this also the best density estimate for the dataset?

# %% [markdown]
# ### **Exercise 4.2**
#
# Use the same data as in the previous exercise, but now split the data into a training and test set of equal size. Estimate a Parzen density on the training set and compute the Parzen density for the test set. Compute the log-likelihood on both the training and test sets for $ h = [0.1, 0.25, 0.5, 1, 1.5, 2, 3, 4, 5] $. Plot these log-likelihood vs. $ h $ curves

# %%
# Split into trn and tst, both 50%
[trn, tst] = pr.gendat(a, 0.5)

# Array of h’s to try
hs = [0.01, 0.05, 0.1, 0.25, 0.5, 1, 1.5, 2, 3, 4, 5]

# Initialize log-likelihood arrays
Ltrn = np.zeros(len(hs))
Ltst = np.zeros(len(hs))

# For each h...
for i in range(len(hs)):
    # Estimate Parzen density
    w = pr.parzenm(trn, hs[i])

    # Calculate trn log-likelihood
    Ltrn[i] = np.sum(np.log(+(trn * w)))

    # Calculate tst log-likelihood
    Ltst[i] = np.sum(np.log(+(tst * w)))

# Plot log-likelihood as function of h
plt.plot(hs, Ltrn, 'b-', label='Training Log-Likelihood')  # Plot trn log-likelihood as function of h
plt.plot(hs, Ltst, 'r-', label='Test Log-Likelihood')      # Plot tst log-likelihood as function of h
plt.xlabel('h')
plt.ylabel('Log-Likelihood')
plt.legend()
plt.show()

# %% [markdown]
# What is a good choice for $ h $?

# %% [markdown]
# ---
